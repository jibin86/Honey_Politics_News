# %%
import pandas as pd

# %%
df = pd.read_csv('news_link_for_portal.csv')
df.columns = ['index', 'title', 'link', 'date']
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = pd.read_csv('data/khan.csv')
#       2 df.columns = ['index', 'title', 'link', 'date']
#       3 df
#
# File c:\Program Files\Python38\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Program Files\Python38\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File c:\Program Files\Python38\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File c:\Program Files\Python38\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File c:\Program Files\Python38\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File c:\Program Files\Python38\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/khan.csv'

# %%
df_body = pd.read_csv('news_body_for_portal.csv', index_col='index')
df_body
# Out:
#                                                     link  \
# index
# 0      https://www.khan.co.kr/politics/politics-gener...
# 1      https://www.khan.co.kr/politics/politics-gener...
# 2      https://www.khan.co.kr/politics/politics-gener...
# 3      https://www.khan.co.kr/politics/politics-gener...
# 4      https://www.khan.co.kr/politics/politics-gener...
# ...                                                  ...
# 125    https://www.khan.co.kr/politics/politics-gener...
# 126    https://www.khan.co.kr/politics/politics-gener...
# 127    https://www.khan.co.kr/politics/politics-gener...
# 128    https://www.khan.co.kr/politics/politics-gener...
# 129    https://www.khan.co.kr/politics/politics-gener...
#
#                                                     body          reporter
# index
# 0      \n나경원 전 의원이 25일 장고 끝에 국민의힘 당대표 선거 불출마를 선언했다. 대...            조문희 기자
# 1      \n윤석열 대통령은 25일 아랍에미리트연합(UAE)·스위스 순방 이후 첫 국무회의를...            유설희 기자
# 2      \n더불어민주당이 25일 설 연휴 기간 시민들의 최대 관심사였던 난방비 폭등 문제를...            탁지영 기자
# 3      \n국민의힘이 윤석열 대통령의 “아랍에미리트연합(UAE)의 적은 이란” 발언과 관련...  조문희 기자    이두리 기자
# 4      \n나경원 전 의원이 25일 국민의힘 대표 선출을 위한 전당대회에 불출마하기로 한 ...            문광호 기자
# ...                                                  ...               ...
# 125    \n국가·공공기관에서 업무용으로 애플 아이폰과 아이패드를 사용할 수 있게 된다.\n...            박광연 기자
# 126    \n김진표 국회의장이 11일 국회 사랑재에서 열린 신년 기자회견에서 윤석열 대통령 ...            신주영 기자
# 127    \n국민의힘 소속인 유승민 전 의원과 홍준표 대구시장이 11일 전직 대통령 박근혜씨...  정대연 기자    문광호 기자
# 128    \n나경원 전 의원이 저출산고령사회위원회 부위원장직 사의 표명과 관련해 11일 “아...            조문희 기자
# 129    \n국민의힘은 11일 전날 검찰 조사를 받은 이재명 더불어민주당 대표에 대해 “권력...            문광호 기자
#
# [130 rows x 3 columns]

# %%
df_body['body'] = df_body['body'].str.replace('\n','')

# %%
df_body
# Out:
#                                                     link  \
# index
# 0      https://www.khan.co.kr/politics/politics-gener...
# 1      https://www.khan.co.kr/politics/politics-gener...
# 2      https://www.khan.co.kr/politics/politics-gener...
# 3      https://www.khan.co.kr/politics/politics-gener...
# 4      https://www.khan.co.kr/politics/politics-gener...
# ...                                                  ...
# 125    https://www.khan.co.kr/politics/politics-gener...
# 126    https://www.khan.co.kr/politics/politics-gener...
# 127    https://www.khan.co.kr/politics/politics-gener...
# 128    https://www.khan.co.kr/politics/politics-gener...
# 129    https://www.khan.co.kr/politics/politics-gener...
#
#                                                     body          reporter
# index
# 0      나경원 전 의원이 25일 장고 끝에 국민의힘 당대표 선거 불출마를 선언했다. 대통령...            조문희 기자
# 1      윤석열 대통령은 25일 아랍에미리트연합(UAE)·스위스 순방 이후 첫 국무회의를 열...            유설희 기자
# 2      더불어민주당이 25일 설 연휴 기간 시민들의 최대 관심사였던 난방비 폭등 문제를 전...            탁지영 기자
# 3      국민의힘이 윤석열 대통령의 “아랍에미리트연합(UAE)의 적은 이란” 발언과 관련해 ...  조문희 기자    이두리 기자
# 4      나경원 전 의원이 25일 국민의힘 대표 선출을 위한 전당대회에 불출마하기로 한 것으...            문광호 기자
# ...                                                  ...               ...
# 125    국가·공공기관에서 업무용으로 애플 아이폰과 아이패드를 사용할 수 있게 된다.국가정보...            박광연 기자
# 126    김진표 국회의장이 11일 국회 사랑재에서 열린 신년 기자회견에서 윤석열 대통령 풍자...            신주영 기자
# 127    국민의힘 소속인 유승민 전 의원과 홍준표 대구시장이 11일 전직 대통령 박근혜씨 탄...  정대연 기자    문광호 기자
# 128    나경원 전 의원이 저출산고령사회위원회 부위원장직 사의 표명과 관련해 11일 “아직 ...            조문희 기자
# 129    국민의힘은 11일 전날 검찰 조사를 받은 이재명 더불어민주당 대표에 대해 “권력의 ...            문광호 기자
#
# [130 rows x 3 columns]

# %%
df_title = pd.read_csv('news_link_for_portal.csv', index_col='index')
df_title
# Out:
#                                                    title  \
# index
# 0              나경원, ‘윤심·윤핵관’에 주저앉았다···“솔로몬의 재판 진짜 엄마 심정”
# 1                           윤 대통령 “글로벌 스탠다드로 정부 시스템 바꿔야”
# 2       ‘난방비 폭등’ 쟁점화한 민주당···30조원 추경에 가구당 최대 40만원 지원 제안까지
# 3       국민의힘 “이란과 북은 군사적 일심동체”…윤 대통령 “UAE 적은 이란” 발언 재점화?
# 4                                      [속보] 나경원, 당대표 불출마
# ...                                                  ...
# 125                     공공 업무용으로 ‘갤럭시’ 대신 ‘아이폰’ 사용 가능해진다
# 126     김진표, ‘윤 대통령 풍자화 철거’에 “특정 개인 모욕 목적으로 국회 쓰이는 건 ...
# 127               유승민·홍준표, 대구서 충돌···“수없이 말 바꿔” VS “연탄가스”
# 128                           “윤석열 정부 성공” 빠르게 삼창한 나경원…왜?
# 129                               국민의힘 “이재명 말 공감, 기소될 것”
#
#                                                     link              date
# index
# 0      https://www.khan.co.kr/politics/politics-gener...             1시간 전
# 1      https://www.khan.co.kr/politics/politics-gener...             1시간 전
# 2      https://www.khan.co.kr/politics/politics-gener...             3시간 전
# 3      https://www.khan.co.kr/politics/politics-gener...             8시간 전
# 4      https://www.khan.co.kr/politics/politics-gener...             9시간 전
# ...                                                  ...               ...
# 125    https://www.khan.co.kr/politics/politics-gener...  2023.01.11 14:43
# 126    https://www.khan.co.kr/politics/politics-gener...  2023.01.11 14:08
# 127    https://www.khan.co.kr/politics/politics-gener...  2023.01.11 14:02
# 128    https://www.khan.co.kr/politics/politics-gener...  2023.01.11 11:22
# 129    https://www.khan.co.kr/politics/politics-gener...  2023.01.11 10:44
#
# [130 rows x 3 columns]

# %%
df_body['title'] = df_title['title']
df_body['date'] = df_title['date']
df_body.head()
# Out:
#                                                     link  \
# index
# 0      https://www.khan.co.kr/politics/politics-gener...
# 1      https://www.khan.co.kr/politics/politics-gener...
# 2      https://www.khan.co.kr/politics/politics-gener...
# 3      https://www.khan.co.kr/politics/politics-gener...
# 4      https://www.khan.co.kr/politics/politics-gener...
#
#                                                     body          reporter  \
# index
# 0      나경원 전 의원이 25일 장고 끝에 국민의힘 당대표 선거 불출마를 선언했다. 대통령...            조문희 기자
# 1      윤석열 대통령은 25일 아랍에미리트연합(UAE)·스위스 순방 이후 첫 국무회의를 열...            유설희 기자
# 2      더불어민주당이 25일 설 연휴 기간 시민들의 최대 관심사였던 난방비 폭등 문제를 전...            탁지영 기자
# 3      국민의힘이 윤석열 대통령의 “아랍에미리트연합(UAE)의 적은 이란” 발언과 관련해 ...  조문희 기자    이두리 기자
# 4      나경원 전 의원이 25일 국민의힘 대표 선출을 위한 전당대회에 불출마하기로 한 것으...            문광호 기자
#
#                                                    title   date
# index
# 0              나경원, ‘윤심·윤핵관’에 주저앉았다···“솔로몬의 재판 진짜 엄마 심정”  1시간 전
# 1                           윤 대통령 “글로벌 스탠다드로 정부 시스템 바꿔야”  1시간 전
# 2       ‘난방비 폭등’ 쟁점화한 민주당···30조원 추경에 가구당 최대 40만원 지원 제안까지  3시간 전
# 3       국민의힘 “이란과 북은 군사적 일심동체”…윤 대통령 “UAE 적은 이란” 발언 재점화?  8시간 전
# 4                                      [속보] 나경원, 당대표 불출마  9시간 전

# %%
idx_edit = df_body[df_body['title'].str.contains('속보')].index
idx_edit
# Out:
# Int64Index([4, 19, 26, 37], dtype='int64', name='index')

# %%
list(idx_edit)
# Out:
# [4, 19, 26, 37]

# %%
df_body.loc[idx_edit,'title'] = df_body.loc[idx_edit,'title'].str.replace('\[속보]', '')
# df_body.loc[idx_edit]['title']
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_31928\4139552948.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_body.loc[idx_edit,'title'] = df_body.loc[idx_edit,'title'].str.replace('\[속보]', '')

# %%
df_body.loc[:10,"link"]
# Out:
# index
# 0     https://www.khan.co.kr/politics/politics-gener...
# 1     https://www.khan.co.kr/politics/politics-gener...
# 2     https://www.khan.co.kr/politics/politics-gener...
# 3     https://www.khan.co.kr/politics/politics-gener...
# 4     https://www.khan.co.kr/politics/politics-gener...
# 5     https://www.khan.co.kr/politics/politics-gener...
# 6     https://www.khan.co.kr/politics/politics-gener...
# 7     https://www.khan.co.kr/politics/politics-gener...
# 8     https://www.khan.co.kr/politics/politics-gener...
# 9     https://www.khan.co.kr/politics/politics-gener...
# 10    https://www.khan.co.kr/politics/politics-gener...
# Name: link, dtype: object

# %%
df_final = df_body.loc[5:104]
df_final = df_final.reset_index()
df_final['news'] = '경향'
df_final.drop(columns=['index'], inplace=True)
df_final
# Out:
#                                                  link  \
# 0   https://www.khan.co.kr/politics/politics-gener...
# 1   https://www.khan.co.kr/politics/politics-gener...
# 2   https://www.khan.co.kr/politics/politics-gener...
# 3   https://www.khan.co.kr/politics/politics-gener...
# 4   https://www.khan.co.kr/politics/politics-gener...
# ..                                                ...
# 95  https://www.khan.co.kr/politics/politics-gener...
# 96  https://www.khan.co.kr/politics/politics-gener...
# 97  https://www.khan.co.kr/politics/politics-gener...
# 98  https://www.khan.co.kr/politics/politics-gener...
# 99  https://www.khan.co.kr/politics/politics-gener...
#
#                                                  body          reporter  \
# 0   지난 9일 소집된 1월 임시국회가 보름 넘게 개점 휴업 중이다. 여야는 국회 공전의...  탁지영 기자    문광호 기자
# 1   국민의힘 당권주자들이 분주한 설 연휴를 보냈다. 당권 경쟁이 크지 않은 지지율 격차...  문광호 기자    이두리 기자
# 2   국민의힘이 24일 설 민심을 전하며 이재명 더불어민주당 대표에 대한 부정적 여론을 ...  이두리 기자    문광호 기자
# 3   김기현 국민의힘 의원이 여성의 군사기본교육 도입을 주장했다. 지난해 10월 발표한 ...            문광호 기자
# 4   여야 양당이 설을 맞아 ‘민생’을 강조하는 메시지를 내놨다. 국민의힘은 윤석열 대통...            김태훈 기자
# ..                                                ...               ...
# 95  더불어민주당은 13일 “북한 무인기 비행금지구역 침범과 군의 대응 실패가 대통령실 ...            탁지영 기자
# 96  윤석열 정부 들어 국정원의 기능과 역할이 다시 커지고 있다. 공직자 인사검증 기능이...   강은 기자    이유진 기자
# 97  국민의힘 당대표 선거 출마를 고심 중인 나경원 전 의원이 오는 13일 저출산고령사회...  문광호 기자    조문희 기자
# 98  더불어민주당은 12일 정부가 일제 강제동원(징용) 피해자 배상 해법으로 일본 피고기...            탁지영 기자
# 99  외교부·국방부 등 다른 외교안보 부처와 합동으로 열렸던 통일부의 새해 대통령 업무보...            박광연 기자
#
#                                             title              date news
# 0                                개점 휴업 중인 1월 임시국회  2023.01.24 15:50   경향
# 1    김기현 ‘20대 남성과 유기견’, 안철수 ‘안보와 윤심’···당권경쟁 다른 코드  2023.01.24 15:12   경향
# 2                  [국민의힘이 전한 설민심] “이재명 대표 피로감 호소”  2023.01.24 13:47   경향
# 3      김기현 “여성 군사기본교육 도입” 재차 주장···군사독재 잔재 ‘교련’ 유사  2023.01.24 10:41   경향
# 4     일제히 ‘민생’ 강조하면서도··· 여 ‘통합’, 야 ‘견제’ 서로 다른 메시지  2023.01.22 14:08   경향
# ..                                            ...               ...  ...
# 95          민주당 “북한 무인기 침범은 대통령실 이전 때문···감사 실시해야”  2023.01.13 11:15   경향
# 96                [단독]다시 몸집 키우는 국정원···국정원 개혁 후퇴하나  2023.01.13 06:00   경향
# 97              나경원, 13일 사직서 낸다···“사의에 대한 확고한 의지”  2023.01.12 20:52   경향
# 98         민주당, 강제동원 정부안에 “피해자 짓밟고 일본 기업 이익 대변하나”  2023.01.12 17:41   경향
# 99        11년만에 통일부 ‘따로’ 업무보고…대북 압박 우선, 대화 후순위 현실  2023.01.12 17:11   경향
#
# [100 rows x 6 columns]

# %%
df_final['reporter'] = df_final['reporter'].str.replace('\xa0\xa0\xa0\xa0',' ')
df_final['reporter']
# Out:
# 0     탁지영 기자 문광호 기자
# 1     문광호 기자 이두리 기자
# 2     이두리 기자 문광호 기자
# 3            문광호 기자
# 4            김태훈 기자
#           ...
# 95           탁지영 기자
# 96     강은 기자 이유진 기자
# 97    문광호 기자 조문희 기자
# 98           탁지영 기자
# 99           박광연 기자
# Name: reporter, Length: 100, dtype: object

# %%
df_final.to_csv('경향_100_link_title_body_reporter_date.csv', index=False)

# %% [markdown]
# # 데이터베이스에 저장할 데이터 합치기

# %%
cho = pd.read_csv('data/chosun_100.csv')
han = pd.read_csv('data/han_100.csv', encoding='cp949')
joog = pd.read_csv('data/joongang_100.csv')
kyung = pd.read_csv('data/khan_100.csv')

# %%
cho.head()
# Out:
#    Unnamed: 0                                               link  \
# 0           0  https://n.news.naver.com/article/023/000374215...
# 1           1  https://n.news.naver.com/article/023/000374212...
# 2           2  https://n.news.naver.com/article/023/000374211...
# 3           3  https://n.news.naver.com/article/023/000374211...
# 4           4  https://n.news.naver.com/article/023/000374211...
#
#                                                 body reporter  \
# 0  김종민 더불어민주당 의원. /뉴스1더불어민주당은 설 연휴 기간 이른바 ‘천원(100...   오경묵 기자
# 1  성일종 국민의힘 정책위의장이 24일 오후 서울 여의도 국회에서 열린 기자간담회에서 ...   김동하 기자
# 2  국민의힘 당권주자인 안철수 의원이 24일 서울 여의도 한 식당에서 열린 설 맞이 북...   김동하 기자
# 3  국민의힘 당권주자인 김기현 의원이 24일 서울 여의도 한 식당에서 열린 '연포탕' ...   김동하 기자
# 4  윤석열 대통령이 24일 서울 용산 대통령실 청사에서 열린 '과학기술 영 리더와의 대...   김동하 기자
#
#                                       title                  date  news
# 0  민주 ‘천원 당원’ 논란에…김종민 “李에 바른 소리 했다고 정치적 공격”  2023.01.24. 오후 10:43  조선일보
# 1        與 “野 추경 주장, 이재명 사법리스크 덮으려는 정략적 발상”   2023.01.24. 오후 3:50  조선일보
# 2       안철수, 김기현 겨냥 “연포탕 외치다 진흙탕 외치니 당황스럽다”   2023.01.24. 오후 3:38  조선일보
# 3            김기현, 연포탕 간담회 “철새 정치인 삶 살지 않았다”   2023.01.24. 오후 3:37  조선일보
# 4        尹대통령, 설연휴 마지막날 과학기술인 오찬 “인재 양성 중요”   2023.01.24. 오후 3:14  조선일보

# %%
han.head()
# Out:
#    Unnamed: 0  index                                 title  \
# 0          35      0    국힘 최고위원 다섯 자리 두고 원내  예열중  원외  후끈
# 1          36      1             윤 대통령  귀국 뒤 첫 행보는  과학기술
# 2          37      2   김기현  여성도 민방위 훈련  남성 당원 표심 노린 갈라치기
# 3          38      3               양강이냐  3파전이냐 나경원 입에 달렸다
# 4          39      4      독도는 일본땅  외치는데도 강제동원 협상 속도 내는 정부
#
#                                              article news  \
# 0  태영호 국민의힘 의원. 공동취재사진 국민의힘 최고위원 선거 경쟁전이 ‘원외’를 중심...  한겨레
# 1  윤석열 대통령이 24일 용산 대통령실에서 ‘과학기술 영 리더와의 대화’ 시간을 갖고...  한겨레
# 2  국민의힘 당권주자인 김기현 의원이 24일 서울 여의도 한 식당에서 열린 ‘연포탕' ...  한겨레
# 3  국민의힘 당대표 선거 출마를 고심 중인 나경원 전 의원이 지난 16일 서울 시내의 ...  한겨레
# 4  하야시 요시마사 일본 외무상. 연합뉴스 일본이 조선 노동자들이 강제 동원된 사도광산...  한겨레
#
#                                                 link  \
# 0  https://www.hani.co.kr//arti/politics/politics...
# 1  https://www.hani.co.kr//arti/politics/politics...
# 2  https://www.hani.co.kr//arti/politics/politics...
# 3  https://www.hani.co.kr//arti/politics/politics...
# 4  https://www.hani.co.kr//arti/politics/diplomac...
#
#                                            date  \
# 0  등록 : 2023-01-24 18:32 수정 : 2023-01-25 02:14
# 1  등록 : 2023-01-24 18:28 수정 : 2023-01-25 02:15
# 2  등록 : 2023-01-24 18:24 수정 : 2023-01-25 02:15
# 3  등록 : 2023-01-24 18:22 수정 : 2023-01-25 02:13
# 4  등록 : 2023-01-24 18:20 수정 : 2023-01-25 08:56
#
#                                           reporter
# 0                        오연서 기자
# 1                        김미나 기자
# 2                         오연서 기자
# 3    송채경화 기자      김해정 기자     오연서 기자
# 4             신형철 기자     김미나 기자

# %%
joog.head()
# Out:
#    Unnamed: 0                                               link  \
# 0           0  https://n.news.naver.com/article/025/000325515...
# 1           1  https://n.news.naver.com/article/025/000325514...
# 2           2  https://n.news.naver.com/article/025/000325514...
# 3           3  https://n.news.naver.com/article/025/000325514...
# 4           4  https://n.news.naver.com/article/025/000325514...
#
#                                                 body reporter  \
# 0  김정은 북한 국무위원장이 과거 도널드 트럼프 미국 전 대통령이 그에게 붙인 별명 ‘...   배재성 기자
# 1  북한이 지난해 신종 코로나바이러스 감염증(코로나19) 극복 성과를 선전하는 다큐멘터...   배재성 기자
# 2  북한 매체가 윤석열 대통령의 아랍에미리트(UAE) 방문 당시 발언을 비난하고 나섰다...   하수영 기자
# 3  국민의힘 당권주자로 거론되는 나경원 전 의원이 24일  3·8 국민의힘 전당대회 출...   배재성 기자
# 4  28일로 예정된 검찰 출석을 앞두고 이재명 민주당 대표는 설 연휴 기간(21~24일...   성지원 기자
#
#                                    title                  date  news
# 0        “김정은, 트럼프에 ‘로켓맨’은 OK, ‘리틀’은 NO”  2023.01.24. 오후 11:01  중앙일보
# 1       북한, 코로나19 극복 다큐 방영…“80여일만 종식 기적”   2023.01.24. 오후 9:39  중앙일보
# 2  北매체, 尹 'UAE 적은 이란' 발언 비난 "해당 나라 분노했다"   2023.01.24. 오후 7:49  중앙일보
# 3         나경원, 내일 전대 출마 여부 입장 발표…“결심 섰다”   2023.01.24. 오후 7:17  중앙일보
# 4   檢 출석 앞둔 이재명, '처럼회'와 회동…비명계는 별도 모임 발족   2023.01.24. 오후 6:58  중앙일보

# %%
kyung.head()
# Out:
#                                                 link  \
# 0  https://www.khan.co.kr/politics/politics-gener...
# 1  https://www.khan.co.kr/politics/politics-gener...
# 2  https://www.khan.co.kr/politics/politics-gener...
# 3  https://www.khan.co.kr/politics/politics-gener...
# 4  https://www.khan.co.kr/politics/politics-gener...
#
#                                                 body       reporter  \
# 0  지난 9일 소집된 1월 임시국회가 보름 넘게 개점 휴업 중이다. 여야는 국회 공전의...  탁지영 기자 문광호 기자
# 1  국민의힘 당권주자들이 분주한 설 연휴를 보냈다. 당권 경쟁이 크지 않은 지지율 격차...  문광호 기자 이두리 기자
# 2  국민의힘이 24일 설 민심을 전하며 이재명 더불어민주당 대표에 대한 부정적 여론을 ...  이두리 기자 문광호 기자
# 3  김기현 국민의힘 의원이 여성의 군사기본교육 도입을 주장했다. 지난해 10월 발표한 ...         문광호 기자
# 4  여야 양당이 설을 맞아 ‘민생’을 강조하는 메시지를 내놨다. 국민의힘은 윤석열 대통...         김태훈 기자
#
#                                            title              date news
# 0                               개점 휴업 중인 1월 임시국회  2023.01.24 15:50   경향
# 1   김기현 ‘20대 남성과 유기견’, 안철수 ‘안보와 윤심’···당권경쟁 다른 코드  2023.01.24 15:12   경향
# 2                 [국민의힘이 전한 설민심] “이재명 대표 피로감 호소”  2023.01.24 13:47   경향
# 3     김기현 “여성 군사기본교육 도입” 재차 주장···군사독재 잔재 ‘교련’ 유사  2023.01.24 10:41   경향
# 4    일제히 ‘민생’ 강조하면서도··· 여 ‘통합’, 야 ‘견제’ 서로 다른 메시지  2023.01.22 14:08   경향

# %% [markdown]
# ## 날짜를 string에서 datetime 타입으로 통일하기

# %% [markdown]
# ### 경향

# %%
kyung['date']
# Out:
# 0     2023.01.24 15:50
# 1     2023.01.24 15:12
# 2     2023.01.24 13:47
# 3     2023.01.24 10:41
# 4     2023.01.22 14:08
#             ...
# 95    2023.01.13 11:15
# 96    2023.01.13 06:00
# 97    2023.01.12 20:52
# 98    2023.01.12 17:41
# 99    2023.01.12 17:11
# Name: date, Length: 100, dtype: object

# %%
from datetime import datetime, timedelta

datetime_string = "2023.01.22 14:08"
datetime_format = "%Y.%m.%d %H:%M"

datetime_result = datetime.strptime(datetime_string, datetime_format)
print(type(datetime_result)) # <class 'datetime.datetime'>
print(datetime_result) # 2021-12-31 13:35:42.657813

kyung['date'] = kyung['date'].apply(lambda _ : datetime.strptime(_,datetime_format))
kyung['date']
# Out:
# <class 'datetime.datetime'>
# 2023-01-22 14:08:00
# 0    2023-01-24 15:50:00
# 1    2023-01-24 15:12:00
# 2    2023-01-24 13:47:00
# 3    2023-01-24 10:41:00
# 4    2023-01-22 14:08:00
#              ...
# 95   2023-01-13 11:15:00
# 96   2023-01-13 06:00:00
# 97   2023-01-12 20:52:00
# 98   2023-01-12 17:41:00
# 99   2023-01-12 17:11:00
# Name: date, Length: 100, dtype: datetime64[ns]

# %% [markdown]
# ### 조선일보

# %%
am_idx = cho[cho['date'].str.contains('오전')].index
pm_idx = cho[cho['date'].str.contains('오후')].index

datetime_string = "2023.01.24. 오전 10:43"
datetime_format_am = "%Y.%m.%d. 오전 %H:%M"
datetime_format_pm = "%Y.%m.%d. 오후 %H:%M"

cho.loc[am_idx,'date'] = cho.loc[am_idx,'date'].apply(lambda _ : datetime.strptime(_,datetime_format_am))
cho.loc[pm_idx,'date'] = cho.loc[pm_idx,'date'].apply(lambda _ : datetime.strptime(_,datetime_format_pm))
cho.loc[pm_idx,'date'] = cho.loc[pm_idx,'date'] + timedelta(hours=12)

# %%
cho.head()
# Out:
#    Unnamed: 0                                               link  \
# 0           0  https://n.news.naver.com/article/023/000374215...
# 1           1  https://n.news.naver.com/article/023/000374212...
# 2           2  https://n.news.naver.com/article/023/000374211...
# 3           3  https://n.news.naver.com/article/023/000374211...
# 4           4  https://n.news.naver.com/article/023/000374211...
#
#                                                 body reporter  \
# 0  김종민 더불어민주당 의원. /뉴스1더불어민주당은 설 연휴 기간 이른바 ‘천원(100...   오경묵 기자
# 1  성일종 국민의힘 정책위의장이 24일 오후 서울 여의도 국회에서 열린 기자간담회에서 ...   김동하 기자
# 2  국민의힘 당권주자인 안철수 의원이 24일 서울 여의도 한 식당에서 열린 설 맞이 북...   김동하 기자
# 3  국민의힘 당권주자인 김기현 의원이 24일 서울 여의도 한 식당에서 열린 '연포탕' ...   김동하 기자
# 4  윤석열 대통령이 24일 서울 용산 대통령실 청사에서 열린 '과학기술 영 리더와의 대...   김동하 기자
#
#                                       title                 date  news
# 0  민주 ‘천원 당원’ 논란에…김종민 “李에 바른 소리 했다고 정치적 공격”  2023-01-24 22:43:00  조선일보
# 1        與 “野 추경 주장, 이재명 사법리스크 덮으려는 정략적 발상”  2023-01-24 15:50:00  조선일보
# 2       안철수, 김기현 겨냥 “연포탕 외치다 진흙탕 외치니 당황스럽다”  2023-01-24 15:38:00  조선일보
# 3            김기현, 연포탕 간담회 “철새 정치인 삶 살지 않았다”  2023-01-24 15:37:00  조선일보
# 4        尹대통령, 설연휴 마지막날 과학기술인 오찬 “인재 양성 중요”  2023-01-24 15:14:00  조선일보

# %% [markdown]
# ### 한겨레

# %%
han = pd.read_csv('data/hani2.csv', encoding='cp949')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 han = pd.read_csv('data/hani2.csv', encoding='cp949')
#
# File c:\Program Files\Python38\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Program Files\Python38\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File c:\Program Files\Python38\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File c:\Program Files\Python38\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File c:\Program Files\Python38\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File c:\Program Files\Python38\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/hani2.csv'

# %%
han['date'] = han['date'].apply(lambda x : x[:21])

# %%
han['date'][0]
# Out:
# '등록 : 2023-01-24 18:32 수정 : 2023-01-25 02:14 '

# %%
datetime_string = "등록 : 2023-01-24 18:32"
datetime_format = "등록 : %Y-%m-%d %H:%M"
han['date'] = han['date'].apply(lambda _ : datetime.strptime(_,datetime_format))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 3
#       1 datetime_string = "등록 : 2023-01-24 18:32"
#       2 datetime_format = "등록 : %Y-%m-%d %H:%M"
# ----> 3 han['date'] = han['date'].apply(lambda _ : datetime.strptime(_,datetime_format))
#
# File c:\Program Files\Python38\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\Program Files\Python38\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File c:\Program Files\Python38\lib\site-packages\pandas\core\apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Program Files\Python38\lib\site-packages\pandas\_libs\lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# Cell In[25], line 3, in <lambda>(_)
#       1 datetime_string = "등록 : 2023-01-24 18:32"
#       2 datetime_format = "등록 : %Y-%m-%d %H:%M"
# ----> 3 han['date'] = han['date'].apply(lambda _ : datetime.strptime(_,datetime_format))
#
# File c:\Program Files\Python38\lib\_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File c:\Program Files\Python38\lib\_strptime.py:352, in _strptime(data_string, format)
#     349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
#     351 if len(data_string) != found.end():
# --> 352     raise ValueError("unconverted data remains: %s" %
#     353                       data_string[found.end():])
#     355 iso_year = year = None
#     356 month = day = 1
#
# ValueError: unconverted data remains:  수정 : 2023-01-25 02:14

# %%
han['date'][0]
# Out:
# Timestamp('2023-01-24 18:32:00')

# %% [markdown]
# ### 중앙일보

# %%
joog['date'][0]
# Out:
# '2023.01.24. 오후 11:01'

# %%
am_idx = joog[joog['date'].str.contains('오전')].index
pm_idx = joog[joog['date'].str.contains('오후')].index

datetime_string = "2023.01.24. 오전 10:43"
datetime_format_am = "%Y.%m.%d. 오전 %H:%M"
datetime_format_pm = "%Y.%m.%d. 오후 %H:%M"

joog.loc[am_idx,'date'] = joog.loc[am_idx,'date'].apply(lambda _ : datetime.strptime(_,datetime_format_am))
joog.loc[pm_idx,'date'] = joog.loc[pm_idx,'date'].apply(lambda _ : datetime.strptime(_,datetime_format_pm))
joog.loc[pm_idx,'date'] = joog.loc[pm_idx,'date'] + timedelta(hours=12)

# %%
joog['date'][0]
# Out:
# Timestamp('2023-01-24 23:01:00')

# %% [markdown]
# ## 4개의 신문사 하나의 데이터프레임으로 합치기
# - joog, han, cho, kyung

# %%
joog = joog.drop(columns=['Unnamed: 0'])
han = han.drop(columns=['Unnamed: 0', 'index'])
cho = cho.drop(columns=['Unnamed: 0'])

# %%
han = han.rename(columns={'article':'body'})

# %%
all_df= pd.concat([joog, han, cho, kyung],axis=0)
all_df
# Out:
#                                                  link  \
# 0   https://n.news.naver.com/article/025/000325515...
# 1   https://n.news.naver.com/article/025/000325514...
# 2   https://n.news.naver.com/article/025/000325514...
# 3   https://n.news.naver.com/article/025/000325514...
# 4   https://n.news.naver.com/article/025/000325514...
# ..                                                ...
# 95  https://www.khan.co.kr/politics/politics-gener...
# 96  https://www.khan.co.kr/politics/politics-gener...
# 97  https://www.khan.co.kr/politics/politics-gener...
# 98  https://www.khan.co.kr/politics/politics-gener...
# 99  https://www.khan.co.kr/politics/politics-gener...
#
#                                                  body       reporter  \
# 0   김정은 북한 국무위원장이 과거 도널드 트럼프 미국 전 대통령이 그에게 붙인 별명 ‘...         배재성 기자
# 1   북한이 지난해 신종 코로나바이러스 감염증(코로나19) 극복 성과를 선전하는 다큐멘터...         배재성 기자
# 2   북한 매체가 윤석열 대통령의 아랍에미리트(UAE) 방문 당시 발언을 비난하고 나섰다...         하수영 기자
# 3   국민의힘 당권주자로 거론되는 나경원 전 의원이 24일  3·8 국민의힘 전당대회 출...         배재성 기자
# 4   28일로 예정된 검찰 출석을 앞두고 이재명 민주당 대표는 설 연휴 기간(21~24일...         성지원 기자
# ..                                                ...            ...
# 95  더불어민주당은 13일 “북한 무인기 비행금지구역 침범과 군의 대응 실패가 대통령실 ...         탁지영 기자
# 96  윤석열 정부 들어 국정원의 기능과 역할이 다시 커지고 있다. 공직자 인사검증 기능이...   강은 기자 이유진 기자
# 97  국민의힘 당대표 선거 출마를 고심 중인 나경원 전 의원이 오는 13일 저출산고령사회...  문광호 기자 조문희 기자
# 98  더불어민주당은 12일 정부가 일제 강제동원(징용) 피해자 배상 해법으로 일본 피고기...         탁지영 기자
# 99  외교부·국방부 등 다른 외교안보 부처와 합동으로 열렸던 통일부의 새해 대통령 업무보...         박광연 기자
#
#                                        title                 date  news
# 0            “김정은, 트럼프에 ‘로켓맨’은 OK, ‘리틀’은 NO”  2023-01-24 23:01:00  중앙일보
# 1           북한, 코로나19 극복 다큐 방영…“80여일만 종식 기적”  2023-01-24 21:39:00  중앙일보
# 2      北매체, 尹 'UAE 적은 이란' 발언 비난 "해당 나라 분노했다"  2023-01-24 19:49:00  중앙일보
# 3             나경원, 내일 전대 출마 여부 입장 발표…“결심 섰다”  2023-01-24 19:17:00  중앙일보
# 4       檢 출석 앞둔 이재명, '처럼회'와 회동…비명계는 별도 모임 발족  2023-01-24 18:58:00  중앙일보
# ..                                       ...                  ...   ...
# 95     민주당 “북한 무인기 침범은 대통령실 이전 때문···감사 실시해야”  2023-01-13 11:15:00    경향
# 96           [단독]다시 몸집 키우는 국정원···국정원 개혁 후퇴하나  2023-01-13 06:00:00    경향
# 97         나경원, 13일 사직서 낸다···“사의에 대한 확고한 의지”  2023-01-12 20:52:00    경향
# 98    민주당, 강제동원 정부안에 “피해자 짓밟고 일본 기업 이익 대변하나”  2023-01-12 17:41:00    경향
# 99   11년만에 통일부 ‘따로’ 업무보고…대북 압박 우선, 대화 후순위 현실  2023-01-12 17:11:00    경향
#
# [400 rows x 6 columns]

# %%
all_df = all_df.reset_index()
all_df = all_df.drop(columns=['index'])

# %%
all_df
# Out:
#                                                   link  \
# 0    https://n.news.naver.com/article/025/000325515...
# 1    https://n.news.naver.com/article/025/000325514...
# 2    https://n.news.naver.com/article/025/000325514...
# 3    https://n.news.naver.com/article/025/000325514...
# 4    https://n.news.naver.com/article/025/000325514...
# ..                                                 ...
# 395  https://www.khan.co.kr/politics/politics-gener...
# 396  https://www.khan.co.kr/politics/politics-gener...
# 397  https://www.khan.co.kr/politics/politics-gener...
# 398  https://www.khan.co.kr/politics/politics-gener...
# 399  https://www.khan.co.kr/politics/politics-gener...
#
#                                                   body       reporter  \
# 0    김정은 북한 국무위원장이 과거 도널드 트럼프 미국 전 대통령이 그에게 붙인 별명 ‘...         배재성 기자
# 1    북한이 지난해 신종 코로나바이러스 감염증(코로나19) 극복 성과를 선전하는 다큐멘터...         배재성 기자
# 2    북한 매체가 윤석열 대통령의 아랍에미리트(UAE) 방문 당시 발언을 비난하고 나섰다...         하수영 기자
# 3    국민의힘 당권주자로 거론되는 나경원 전 의원이 24일  3·8 국민의힘 전당대회 출...         배재성 기자
# 4    28일로 예정된 검찰 출석을 앞두고 이재명 민주당 대표는 설 연휴 기간(21~24일...         성지원 기자
# ..                                                 ...            ...
# 395  더불어민주당은 13일 “북한 무인기 비행금지구역 침범과 군의 대응 실패가 대통령실 ...         탁지영 기자
# 396  윤석열 정부 들어 국정원의 기능과 역할이 다시 커지고 있다. 공직자 인사검증 기능이...   강은 기자 이유진 기자
# 397  국민의힘 당대표 선거 출마를 고심 중인 나경원 전 의원이 오는 13일 저출산고령사회...  문광호 기자 조문희 기자
# 398  더불어민주당은 12일 정부가 일제 강제동원(징용) 피해자 배상 해법으로 일본 피고기...         탁지영 기자
# 399  외교부·국방부 등 다른 외교안보 부처와 합동으로 열렸던 통일부의 새해 대통령 업무보...         박광연 기자
#
#                                         title                 date  news
# 0             “김정은, 트럼프에 ‘로켓맨’은 OK, ‘리틀’은 NO”  2023-01-24 23:01:00  중앙일보
# 1            북한, 코로나19 극복 다큐 방영…“80여일만 종식 기적”  2023-01-24 21:39:00  중앙일보
# 2       北매체, 尹 'UAE 적은 이란' 발언 비난 "해당 나라 분노했다"  2023-01-24 19:49:00  중앙일보
# 3              나경원, 내일 전대 출마 여부 입장 발표…“결심 섰다”  2023-01-24 19:17:00  중앙일보
# 4        檢 출석 앞둔 이재명, '처럼회'와 회동…비명계는 별도 모임 발족  2023-01-24 18:58:00  중앙일보
# ..                                        ...                  ...   ...
# 395     민주당 “북한 무인기 침범은 대통령실 이전 때문···감사 실시해야”  2023-01-13 11:15:00    경향
# 396           [단독]다시 몸집 키우는 국정원···국정원 개혁 후퇴하나  2023-01-13 06:00:00    경향
# 397         나경원, 13일 사직서 낸다···“사의에 대한 확고한 의지”  2023-01-12 20:52:00    경향
# 398    민주당, 강제동원 정부안에 “피해자 짓밟고 일본 기업 이익 대변하나”  2023-01-12 17:41:00    경향
# 399   11년만에 통일부 ‘따로’ 업무보고…대북 압박 우선, 대화 후순위 현실  2023-01-12 17:11:00    경향
#
# [400 rows x 6 columns]

# %%
# 앞뒤 공백 제거
all_df['title'] = all_df['title'].str.strip()
all_df['body'] = all_df['body'].str.strip()
all_df['reporter'] = all_df['reporter'].str.strip()

# %% [markdown]
# ## [ ]가 들어간 title에서 [ ] delete하기

# %%
all_df[all_df['title'].str.startswith("[")]
# Out:
#                                                   link  \
# 92   https://n.news.naver.com/article/025/000325452...
# 210  https://n.news.naver.com/article/023/000374206...
# 265  https://n.news.naver.com/article/023/000374166...
# 302  https://www.khan.co.kr/politics/politics-gener...
# 325  https://www.khan.co.kr/politics/politics-gener...
# 347  https://www.khan.co.kr/politics/politics-gener...
# 365  https://www.khan.co.kr/politics/politics-gener...
# 368  https://www.khan.co.kr/politics/politics-gener...
# 392  https://www.khan.co.kr/politics/politics-gener...
# 396  https://www.khan.co.kr/politics/politics-gener...
#
#                                                   body        reporter  \
# 92   외교부는 19일 '아랍에미리트(UAE)의 적은 이란'이라는 윤석열 대통령의 발언에 ...          한지혜 기자
# 210  2014년3월 경기도 파주에서 발견된 북한 소형 무인기. 레이더에 작게 탐지되기 위...          유용원 군사
# 265  배성룡·김일진·전지선·리광진과 40대 1명당국 “민노총 보건의료노조 실장 2019년...          노석조 기자
# 302  국민의힘이 24일 설 민심을 전하며 이재명 더불어민주당 대표에 대한 부정적 여론을 ...   이두리 기자 문광호 기자
# 325  이용우 민주당 의원은 19일 경향신문과의 인터뷰에서 “당 지도부가 민생 문제에 대해...          탁지영 기자
# 347  국회 이태원 참사 국정조사 특별위원회 위원장인 우상호 더불어민주당 의원은 17일 국...  탁지영 기자 김윤나영 기자
# 365  “국민의힘 당원이 되겠다고들 하십니다. 얼마 만입니까. 눈물이 납니다.”(정진석 국...          문광호 기자
# 368  윤석열 대통령 국정수행 지지도가 39.3%라는 리얼미터의 여론조사 결과가 16일 나...          문광호 기자
# 392  이탄희 더불어민주당 의원은 13일 대통령 선거에서 결선투표제를 도입하는 내용의 공직...          탁지영 기자
# 396  윤석열 정부 들어 국정원의 기능과 역할이 다시 커지고 있다. 공직자 인사검증 기능이...    강은 기자 이유진 기자
#
#                                                  title                 date  \
# 92           [속보] 외교부, 주한 이란대사 초치…“NPT 문제제기, 전혀 근거 없어”  2023-01-19 14:41:00
# 210  [유용원의 밀리터리 시크릿] 원전 등 국가 중요시설 北 드론 공격 제대로 막을 수 ...  2023-01-24 12:01:00
# 265                   [단독] “민노총 간부들과 접선한 北 공작원은 모두 5명”  2023-01-20 05:01:00
# 302                     [국민의힘이 전한 설민심] “이재명 대표 피로감 호소”  2023-01-24 13:47:00
# 325      [위기의 민주당] ①이용우 “수사 방어에 급급하고, 경제정책은 ‘로빈훗식’ 발상”  2023-01-19 17:22:00
# 347  [인터뷰] 우상호 국조특위위원장 “국정조사, 유가족 눈물로 시작하고 끝나···2차 ...  2023-01-17 17:08:00
# 365      [단독]국민의힘 당원가입 이유가 전광훈?···검색량으로 분석한 당심, 누구 뽑을까  2023-01-16 15:11:00
# 368         [리얼미터]윤 대통령 지지율 5주 만에 30%대···나경원 해임한 날 38%  2023-01-16 08:31:00
# 392  [스팟+터뷰] 이탄희, ‘대선 결선투표제법’ 발의···“반사이익 노리는 혐오정치 끝내야”  2023-01-13 16:09:00
# 396                    [단독]다시 몸집 키우는 국정원···국정원 개혁 후퇴하나  2023-01-13 06:00:00
#
#      news
# 92   중앙일보
# 210  조선일보
# 265  조선일보
# 302    경향
# 325    경향
# 347    경향
# 365    경향
# 368    경향
# 392    경향
# 396    경향

# %%
edit_idx = all_df[all_df['title'].str.startswith("[")].index
edit_idx
# Out:
# Int64Index([92, 210, 265, 302, 325, 347, 365, 368, 392, 396], dtype='int64')

# %%
all_df.loc[[92, 210, 265, 302, 325, 347, 365, 368, 392, 396],'title']
# Out:
# 92             [속보] 외교부, 주한 이란대사 초치…“NPT 문제제기, 전혀 근거 없어”
# 210    [유용원의 밀리터리 시크릿] 원전 등 국가 중요시설 北 드론 공격 제대로 막을 수 ...
# 265                     [단독] “민노총 간부들과 접선한 北 공작원은 모두 5명”
# 302                       [국민의힘이 전한 설민심] “이재명 대표 피로감 호소”
# 325        [위기의 민주당] ①이용우 “수사 방어에 급급하고, 경제정책은 ‘로빈훗식’ 발상”
# 347    [인터뷰] 우상호 국조특위위원장 “국정조사, 유가족 눈물로 시작하고 끝나···2차 ...
# 365        [단독]국민의힘 당원가입 이유가 전광훈?···검색량으로 분석한 당심, 누구 뽑을까
# 368           [리얼미터]윤 대통령 지지율 5주 만에 30%대···나경원 해임한 날 38%
# 392    [스팟+터뷰] 이탄희, ‘대선 결선투표제법’ 발의···“반사이익 노리는 혐오정치 끝내야”
# 396                      [단독]다시 몸집 키우는 국정원···국정원 개혁 후퇴하나
# Name: title, dtype: object

# %% [markdown]
# 속보, 스팟+터뷰, 단독, 인터뷰는 자연어처리 사전에 추가하기

# %% [markdown]
# ## csv로 저장하기

# %%
all_df.to_csv('portal_news.csv')
